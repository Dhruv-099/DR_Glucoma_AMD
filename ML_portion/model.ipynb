# %%
import os
import glob
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split      # dividing the dataset
from sklearn.preprocessing import LabelEncoder            # for converting str labels to number
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import ConfusionMatrixDisplay
from PIL import Image
from collections import defaultdict
import matplotlib.pyplot as plt
import seaborn as sn
import random


os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # 0 = all messages, 1 = filter INFO, 2 = filter WARNING, 3 = filter ERROR
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping , ModelCheckpoint ,Callback # type: ignore
from tensorflow.keras import layers, models ,optimizers # type: ignore
from tensorflow.keras.models import load_model # type: ignore
from tensorflow.keras.layers import GlobalAveragePooling2D # type: ignore
from tensorflow.keras.applications import EfficientNetB0 # type: ignore
import pathlib

import warnings
warnings.filterwarnings("ignore")

# %%
tf.version.VERSION
# Out:
# '2.17.0'

# %%
# Basic review of the photos directory

def dataset_analysis(path):
    subfolders = os.listdir(path)

    for subfolder in subfolders:
        subfolder_path = os.path.join(path, subfolder)
        if os.path.isdir(subfolder_path):
            files = os.listdir(subfolder_path)
            format_dimensions_counts = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))

            for file in files:
                try:
                    file_path = os.path.join(subfolder_path, file)
                    with Image.open(file_path) as img:
                        image_type = img.format.upper()  # Format (e.g., JPEG, PNG)
                        image_dimensions = img.size  # (width, height)
                        image_mode = img.mode  # Mode (e.g., RGB, L)


                        # Calculate bit depth
                        if image_mode == "1":  # 1-bit pixels, black and white, stored with one pixel per byte
                            bit_depth = 1
                        elif image_mode == "L":  # 8-bit pixels, grayscale
                            bit_depth = 8
                        elif image_mode == "P":  # 8-bit pixels, mapped to any other mode using a color palette
                            bit_depth = 8
                        elif image_mode == "RGB":  # 8-bit pixels, true color
                            bit_depth = 24  # 8 bits per channel
                        elif image_mode == "RGBA":  # 8-bit pixels, true color with transparency mask
                            bit_depth = 32  # 8 bits per channel
                        elif image_mode == "CMYK":  # 8-bit pixels, color separation
                            bit_depth = 32  # 8 bits per channel
                        else:
                            bit_depth = "Unknown"

                        format_dimensions_counts[image_type][(image_dimensions, bit_depth)][image_mode] += 1
                except Exception as e:
                    print(f"Exception processing '{file}' in '{subfolder}': {e}")

            print('--------'*10)
            print(f"Subfolder '{subfolder}' contains ({len(files)} files):")
            for format, dimensions_counts in format_dimensions_counts.items():
                print(f"- {sum(sum(counts.values()) for counts in dimensions_counts.values())} images of format {format}:")
                for (dimensions, bit_depth), counts in dimensions_counts.items():
                    for mode, count in counts.items():
                        print(f"  - {count} images with dimensions {dimensions}, bit depth {bit_depth}, mode {mode}")



path = r'/content/drive/MyDrive/dataset'
dataset_path = path
dataset_analysis(dataset_path)
# Out:
# --------------------------------------------------------------------------------
# Subfolder 'normal' contains (1074 files):
# - 1074 images of format JPEG:
#   - 1074 images with dimensions (512, 512), bit depth 24, mode RGB
# --------------------------------------------------------------------------------
# Subfolder 'diabetic_retinopathy' contains (710 files):
# - 710 images of format JPEG:
#   - 710 images with dimensions (512, 512), bit depth 24, mode RGB
# --------------------------------------------------------------------------------
# Subfolder 'glaucoma' contains (1007 files):
# - 906 images of format JPEG:
#   - 306 images with dimensions (512, 512), bit depth 24, mode RGB
#   - 600 images with dimensions (256, 256), bit depth 24, mode RGB
# - 101 images of format PNG:
#   - 74 images with dimensions (2592, 1728), bit depth 24, mode RGB
#   - 22 images with dimensions (2464, 1632), bit depth 24, mode RGB
#   - 5 images with dimensions (1848, 1224), bit depth 24, mode RGB
# --------------------------------------------------------------------------------
# Subfolder 'cataract' contains (1038 files):
# - 938 images of format JPEG:
#   - 298 images with dimensions (512, 512), bit depth 24, mode RGB
#   - 640 images with dimensions (256, 256), bit depth 24, mode RGB
# - 100 images of format PNG:
#   - 5 images with dimensions (1848, 1224), bit depth 24, mode RGB
#   - 76 images with dimensions (2592, 1728), bit depth 24, mode RGB
#   - 19 images with dimensions (2464, 1632), bit depth 24, mode RGB

# %%
# Count the number of images in each directory
subfolders = os.listdir(path)

image_counts = []
for directory in subfolders:
    sub_dir = os.path.join(path, directory)
    if os.path.isdir(sub_dir):
        file_count = len(os.listdir(sub_dir))
        image_counts.append(file_count)

#Add value counts on each bar
for i in range(len(subfolders)):
    plt.text(i, image_counts[i], str(image_counts[i]), ha='center', va='bottom')

#Set some colors
colors = ['lightskyblue', 'mediumseagreen', 'indianred', 'orange']

# Plotting the results
plt.bar(subfolders, image_counts, color=colors)
plt.xlabel('Directory')
plt.xticks(rotation = 45)
plt.ylabel('Number of Images')
plt.title('Number of Images in Each Directory')
plt.show()

# %%
# Check the photos by size

def dataset_size_analysis(path):
    format_dimensions_counts = defaultdict(int)

    subfolders = os.listdir(path)
    for subfolder in subfolders:
        subfolder_path = os.path.join(path, subfolder)
        if os.path.isdir(subfolder_path):
            files = os.listdir(subfolder_path)

            for file in files:
                try:
                    file_path = os.path.join(subfolder_path, file)
                    with Image.open(file_path) as img:
                        image_dimensions = img.size
                        image_mode = img.mode

                        # Calculate bit depth
                        bit_depth = {
                            "1": 1,
                            "L": 8,
                            "P": 8,
                            "RGB": 24,
                            "RGBA": 32,
                            "CMYK": 32
                        }.get(image_mode, "Unknown")

                        # Update counts
                        format_dimensions_counts[(image_dimensions, bit_depth)] += 1

                except Exception as e:
                    print(f"Exception processing '{file}' in '{subfolder}': {e}")

    # Plotting dimensions and bit depths
    plt.figure(figsize=(10, 5))
    labels = [f"{dims}, {depth} bit" for (dims, depth) in format_dimensions_counts]
    sizes = list(format_dimensions_counts.values())
    total = sum(sizes)
    bars = plt.bar(labels, sizes, color='blue')
    plt.xticks(rotation=45, ha="right")
    plt.ylabel('Number of Images')
    plt.title('Image Distribution by Dimensions and Bit Depth')

    # Adding percentage labels above the bars
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, yval, f'{100 * yval/total:.1f}%', ha='center', va='bottom')

    plt.tight_layout()
    plt.show()

# Set the path to the dataset directory
dataset_size_analysis(path)

# %%
def dataset_size_analysis(path):
    # Dictionary to store counts: {subfolder: {image_size: count}}
    folder_size_counts = defaultdict(lambda: defaultdict(int))

    for subfolder in os.listdir(path):
        subfolder_path = os.path.join(path, subfolder)
        if os.path.isdir(subfolder_path):
            for file in os.listdir(subfolder_path):
                try:
                    file_path = os.path.join(subfolder_path, file)
                    with Image.open(file_path) as img:
                        dims = img.size
                        folder_size_counts[subfolder][dims] += 1
                except Exception as e:
                    print(f"Exception processing '{file}' in '{subfolder}': {e}")

    # Create a single plot
    plt.figure(figsize=(15, 7))

    # Determine unique image sizes across all folders for consistent coloring and grouping
    all_sizes = set(size for sizes in folder_size_counts.values() for size in sizes)
    all_sizes = sorted(all_sizes, key=lambda s: (s[0] * s[1]))  # Sort by area

    subfolder_names = list(folder_size_counts.keys())
    bar_width = 0.15  # Width of bars
    indices = range(len(subfolder_names))

    for i, size in enumerate(all_sizes):
        counts = [folder_size_counts[subfolder].get(size, 0) for subfolder in subfolder_names]
        plt.bar([index + i * bar_width for index in indices], counts, bar_width, label=f'{size[0]}x{size[1]}')

    plt.xticks([index + (len(all_sizes) - 1) * bar_width / 2 for index in indices], subfolder_names, rotation=45, ha="right")
    plt.ylabel('Number of Images')
    plt.title('Image Size Distribution by Subfolder')
    plt.legend(title="Image Size")
    plt.tight_layout()
    plt.show()

# Set the path to the dataset directory
dataset_size_analysis(path)

# %%
# Preview photos

def random_photos_from_folders(base_folder):
    # Walk through all directories and files in the base_folder
    for root, dirs, files in os.walk(base_folder):
        # Filter to get only files that are images
        images = [file for file in files if file.lower().endswith(('.png', '.jpg', '.jpeg'))]

        if len(images) >= 4:  # Ensure there are at least 4 images
            selected_images = random.sample(images, 4)  # Randomly select 4 images

            # Display selected images
            fig, axs = plt.subplots(1, 4, figsize=(12, 2))  # Create a 1x4 grid of plots
            for idx, img_name in enumerate(selected_images):
                img_path = os.path.join(root, img_name)
                img = Image.open(img_path)
                axs[idx].imshow(img)
                axs[idx].axis('off')  # Hide axes

                # Extract sub-folder name from the root path
                subfolder_name = os.path.basename(root)
                # Set the title to include image name and sub-folder name
                axs[idx].set_title(f"{img_name}\n({subfolder_name})")

            plt.show()

# Path to the folder containing sub-folders with images

random_photos_from_folders(path)

# %%
# Getting the names of classes
class_dirs = [d for d in os.listdir(path) if os.path.isdir(os.path.join(path, d))]

# create data path and their labeles
data = []
labels = []
extensions = ["jpg", "JPG", "jpeg", "JPEG", "png", "PNG", "bmp", "BMP", "gif", "GIF"]

for i in class_dirs:
    class_label = i
    image_files = []
    for ext in extensions:
        # Search for files with each extension and extend the image_files list
        image_files.extend(glob.glob(os.path.join(path, i, f"*.{ext}")))
    data.extend(image_files)
    labels.extend([class_label] * len(image_files))

# Check if lists are still empty
if not data:
    print("No files were found. Check your directory paths and file formats.")
else:
    print("Files found and listed.")


# Create a DataFrame with the image paths and labels
df = pd.DataFrame({
'filename': data,
'class': labels
})


# Shuffle the dataset by rows
df = df.sample(frac=1)
# Out:
# Files found and listed.

# %%
display(df)
# Out:
#                                                filename                 class
# 2509  /content/drive/MyDrive/dataset/glaucoma/_351_6...              glaucoma
# 3058  /content/drive/MyDrive/dataset/cataract/2244_r...              cataract
# 373   /content/drive/MyDrive/dataset/normal/2808_lef...                normal
# 2480  /content/drive/MyDrive/dataset/glaucoma/_328_7...              glaucoma
# 155   /content/drive/MyDrive/dataset/normal/2583_rig...                normal
# ...                                                 ...                   ...
# 1515  /content/drive/MyDrive/dataset/diabetic_retino...  diabetic_retinopathy
# 2538  /content/drive/MyDrive/dataset/glaucoma/_369_4...              glaucoma
# 159   /content/drive/MyDrive/dataset/normal/2567_rig...                normal
# 1820  /content/drive/MyDrive/dataset/glaucoma/1218_l...              glaucoma
# 3822  /content/drive/MyDrive/dataset/cataract/catara...              cataract
#
# [3829 rows x 2 columns]

# %%
# Convert labels to one-hot encodings
label_encoder = LabelEncoder()
label = label_encoder.fit_transform(df['class'])
df['class'] = label

# check number assigned to each class
# Get the class names and corresponding integer encodings
class_names = label_encoder.classes_
class_numbers = label_encoder.transform(label_encoder.classes_)

# Print class names with the assigned numbers
class_dict = dict(zip(class_names, class_numbers))
print(class_dict)
# Out:
# {'cataract': 0, 'diabetic_retinopathy': 1, 'glaucoma': 2, 'normal': 3}

# %%
display(df)
# Out:
#                                                filename  class
# 2509  /content/drive/MyDrive/dataset/glaucoma/_351_6...      2
# 3058  /content/drive/MyDrive/dataset/cataract/2244_r...      0
# 373   /content/drive/MyDrive/dataset/normal/2808_lef...      3
# 2480  /content/drive/MyDrive/dataset/glaucoma/_328_7...      2
# 155   /content/drive/MyDrive/dataset/normal/2583_rig...      3
# ...                                                 ...    ...
# 1515  /content/drive/MyDrive/dataset/diabetic_retino...      1
# 2538  /content/drive/MyDrive/dataset/glaucoma/_369_4...      2
# 159   /content/drive/MyDrive/dataset/normal/2567_rig...      3
# 1820  /content/drive/MyDrive/dataset/glaucoma/1218_l...      2
# 3822  /content/drive/MyDrive/dataset/cataract/catara...      0
#
# [3829 rows x 2 columns]

# %%
# Check the balance of the classes
print(df['class'].value_counts(normalize=True))
print('------'*10)

# Split the data into train+validation and test sets
train_plus_val, test = train_test_split(df, test_size=0.2, stratify=df['class'], random_state=42)

# Split the train+validation set into train and validation sets
train, val = train_test_split(train_plus_val, test_size=0.25, stratify=train_plus_val['class'], random_state=42)  # 0.25 x 0.8 = 0.2

# Now you have:
# train: 60% of the data
# val: 20% of the data
# test: 20% of the data

# Confirm the distribution across splits
print("Training set:")
print(train['class'].value_counts(normalize=True))
print('------'*10)


print("Validation set:")
print(val['class'].value_counts(normalize=True))
print('------'*10)


print("Test set:")
print(test['class'].value_counts(normalize=True))
# Out:
# class
# 3    0.280491
# 0    0.271089
# 2    0.262993
# 1    0.185427
# Name: proportion, dtype: float64
# ------------------------------------------------------------
# Training set:
# class
# 3    0.280366
# 0    0.270788
# 2    0.263387
# 1    0.185459
# Name: proportion, dtype: float64
# ------------------------------------------------------------
# Validation set:
# class
# 3    0.280679
# 0    0.271540
# 2    0.262402
# 1    0.185379
# Name: proportion, dtype: float64
# ------------------------------------------------------------
# Test set:
# class
# 3    0.280679
# 0    0.271540
# 2    0.262402
# 1    0.185379
# Name: proportion, dtype: float64

# %%
train_links, train_labels = train['filename'].values , train['class'].values
val_links , val_labels = val['filename'].values , val['class'].values
test_links, test_labels = test['filename'].values , test['class'].values

# %%
# Create a Function to Load and Preprocess Images
# tf.cond is a TensorFlow operation that allows for conditional execution based on the value of a tensor.


def load_and_preprocess_image(path, label, data_augmentation=True):
    # Read the image file
    image = tf.io.read_file(path)

    # Extract file extension
    file_extension = tf.strings.split(path, '.')[-1]

    # Decode based on file extension using tf.cond
    def decode_jpeg():
        return tf.image.decode_jpeg(image, channels=3)

    def decode_png():
        return tf.image.decode_png(image, channels=3)

    def decode_bmp():
        return tf.image.decode_bmp(image, channels=3)

    def decode_gif():
        # Decode GIF and take the first frame
        return tf.squeeze(tf.image.decode_gif(image), axis=0)

    # Handle each format
    image = tf.cond(tf.math.equal(file_extension, 'jpg'), decode_jpeg,
            lambda: tf.cond(tf.math.equal(file_extension, 'jpeg'), decode_jpeg,
            lambda: tf.cond(tf.math.equal(file_extension, 'png'), decode_png,
            lambda: tf.cond(tf.math.equal(file_extension, 'bmp'), decode_bmp,
            lambda: tf.cond(tf.math.equal(file_extension, 'gif'), decode_gif,
            decode_jpeg)))))

    # Resize and normalize
    image = tf.image.resize(image, [256, 256])
    image = image / 255.0  # Normalize to [0, 1] range

    # Apply data augmentation if in training mode
    if data_augmentation == True:
        # Randomly flip the image horizontally
        image = tf.image.random_flip_left_right(image)

        # Randomly flip the image vertically
        image = tf.image.random_flip_up_down(image)

        # Randomly rotate the image
        image = tf.image.rot90(image, k=tf.random.uniform(shape=[], minval=0, maxval=4, dtype=tf.int32))

        # Randomly adjust brightness
        image = tf.image.random_brightness(image, max_delta=0.1)

        # Randomly zoom in
        image = tf.image.resize_with_crop_or_pad(image, 266, 266)  # Zoom in slightly
        image = tf.image.random_crop(image, size=[256, 256, 3])

        # Randomly adjust contrast
        image = tf.image.random_contrast(image, lower=0.8, upper=1.2)

    return image, label

# %%
# create TensorFlow datasets for each split
# When loading datasets, pass the data_augmentation flag True or False to apply or skip augmentations:
train_dataset = tf.data.Dataset.from_tensor_slices( (train_links , train_labels) )
train_dataset = train_dataset.map(lambda x, y: load_and_preprocess_image(x, y, data_augmentation=True), num_parallel_calls=tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices( (val_links , val_labels) )
val_dataset = val_dataset.map(lambda x, y: load_and_preprocess_image(x, y, data_augmentation=False), num_parallel_calls=tf.data.AUTOTUNE)

test_dataset = tf.data.Dataset.from_tensor_slices( (test_links , test_labels) )
test_dataset = test_dataset.map(lambda x, y: load_and_preprocess_image(x, y, data_augmentation=False), num_parallel_calls=tf.data.AUTOTUNE)

# %%
# Iterate over the dataset and print the first few elements
for data_element, label_element in train_dataset.take(1):  # Adjust the number to print more/less
    print(f"Data: {data_element.numpy()}, Label: {label_element.numpy()}")
# Out:
# Data: [[[-0.01838291 -0.01210883 -0.00659231]
#   [-0.01838291 -0.01210883 -0.00659231]
#   [-0.01838291 -0.01210883 -0.00659231]
#   ...
#   [-0.01838291 -0.01210883 -0.00659231]
#   [-0.01838291 -0.01210883 -0.00659231]
#   [-0.01838291 -0.01210883 -0.00659231]]
#
#  [[-0.01838291 -0.01210883 -0.00659231]
#   [-0.01838291 -0.01210883 -0.00659231]
#   [-0.01838291 -0.01210883 -0.00659231]
#   ...
#   [-0.01838291 -0.01210883 -0.00659231]
#   [-0.01838291 -0.01210883 -0.00659231]
#   [-0.01838291 -0.01210883 -0.00659231]]
#
#  [[-0.0447447  -0.03847063 -0.0329541 ]
#   [-0.0447447  -0.03847063 -0.0329541 ]
#   [-0.0447447  -0.03847063 -0.0329541 ]
#   ...
#   [-0.01838291 -0.01210883 -0.00659231]
#   [-0.01838291 -0.01210883 -0.00659231]
#   [-0.01838291 -0.01210883 -0.00659231]]
#
#  ...
#
#  [[-0.0447447  -0.03847063 -0.0329541 ]
#   [-0.0447447  -0.03847063 -0.0329541 ]
#   [-0.0447447  -0.03847063 -0.0329541 ]
#   ...
#   [-0.01838291 -0.01210883 -0.00659231]
#   [-0.01838291 -0.01210883 -0.00659231]
#   [-0.01838291 -0.01210883 -0.00659231]]
#
#  [[-0.0447447  -0.03847063 -0.0329541 ]
#   [-0.0447447  -0.03847063 -0.0329541 ]
#   [-0.0447447  -0.03847063 -0.0329541 ]
#   ...
#   [-0.01838291 -0.01210883 -0.00659231]
#   [-0.01838291 -0.01210883 -0.00659231]
#   [-0.01838291 -0.01210883 -0.00659231]]
#
#  [[-0.0447447  -0.03847063 -0.0329541 ]
#   [-0.0447447  -0.03847063 -0.0329541 ]
#   [-0.0447447  -0.03847063 -0.0329541 ]
#   ...
#   [-0.01838291 -0.01210883 -0.00659231]
#   [-0.01838291 -0.01210883 -0.00659231]
#   [-0.01838291 -0.01210883 -0.00659231]]], Label: 3

# %%
# Iterate over the dataset and print the first few elements
for data_element, label_element in train_dataset.take(1):  # Adjust the number to print more/less
    print(f"Data: {data_element.numpy().shape}, Label: {label_element.numpy()}")
# Out:
# Data: (256, 256, 3), Label: 3

# %%
#prepare your datasets for model training and evaluation

batch_size = 16

train_dataset = train_dataset.batch(batch_size)
train_dataset = train_dataset.prefetch(buffer_size= tf.data.AUTOTUNE)

val_dataset = val_dataset.batch(batch_size)
val_dataset = val_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

test_dataset = test_dataset.batch(batch_size)
test_dataset = test_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
##Model Building

# %%
model = models.Sequential([
    # First Block
    layers.Conv2D(128, (3, 3), activation='relu', input_shape=(256, 256, 3), padding='same'),
    layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 2)),
    layers.BatchNormalization(),


    # Second Block
    layers.Conv2D(256, (3, 3), activation='relu',padding='valid'),
    layers.Conv2D(256, (3, 3), activation='relu',padding='valid'),
    layers.MaxPooling2D((2, 2)),
    layers.BatchNormalization(),

    # Second Block
    layers.Conv2D(256, (3, 3), activation='relu',padding='valid'),
    layers.Conv2D(256, (3, 3), activation='relu',padding='valid'),
    layers.MaxPooling2D((2, 2)),
    layers.BatchNormalization(),

    # Second Block
    layers.Conv2D(256, (3, 3), activation='relu',padding='valid'),
    layers.Conv2D(256, (3, 3), activation='relu',padding='valid'),
    layers.MaxPooling2D((2, 2)),
    layers.BatchNormalization(),



    # Global Average Pooling instead of Flatten
    layers.GlobalAveragePooling2D(),

    # Fully Connected Layers
    layers.Dense(512,activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(len(class_names), activation='softmax')  # Output layer
])


model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 256, 256, 128)       │           3,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 256, 256, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 128, 128, 128)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 128, 128, 128)       │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 126, 126, 256)       │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 124, 124, 256)       │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 62, 62, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 62, 62, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 60, 60, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 58, 58, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 29, 29, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 29, 29, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 27, 27, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 25, 25, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 12, 12, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 12, 12, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 256)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │           2,052 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,533,956 (13.48 MB)
#  Trainable params: 3,532,164 (13.47 MB)
#  Non-trainable params: 1,792 (7.00 KB)

# %%
  # Define the EarlyStopping callback to monitor the validation accuracy
early_stopping = EarlyStopping(
    monitor='val_accuracy',  # Monitoring validation accuracy
    patience=12,  # Number of epochs with no improvement after which training will be stopped
    verbose=1,
    mode='max',  # Stops training when the quantity monitored has stopped increasing
    restore_best_weights=True  # Restores model weights from the epoch with the best value of the monitored quantity
)


# Define the ModelCheckpoint callback
model_checkpoint = ModelCheckpoint(
    filepath=r'/home/mojtaba/eye_diseases_classification project/saved model/best_model_custom.keras',  # Path to save the model file
    monitor='val_loss',  # Change to val_loss to monitor the validation loss
    verbose=1,
    save_best_only=True,  # Save only the best model
    mode='min'  # Save the model when the monitored metric has minimized

)


model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])


# Fit the model
history = model.fit(
    x = train_dataset,
    validation_data = val_dataset,
    epochs = 200,
    callbacks=[early_stopping , model_checkpoint]  # Add the EarlyStopping callback
)
# Out:
# Epoch 1/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - accuracy: 0.3077 - loss: 1.5102
# Epoch 1: val_loss improved from inf to 1.62475, saving model to /home/mojtaba/eye_diseases_classification project/saved model/best_model_custom.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 180s 925ms/step - accuracy: 0.3077 - loss: 1.5098 - val_accuracy: 0.2990 - val_loss: 1.6248
# Epoch 2/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step - accuracy: 0.3409 - loss: 1.4203
# Epoch 2: val_loss improved from 1.62475 to 1.35114, saving model to /home/mojtaba/eye_diseases_classification project/saved model/best_model_custom.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 73s 504ms/step - accuracy: 0.3411 - loss: 1.4200 - val_accuracy: 0.3525 - val_loss: 1.3511
# Epoch 3/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - accuracy: 0.4003 - loss: 1.2936
# Epoch 3: val_loss improved from 1.35114 to 1.21577, saving model to /home/mojtaba/eye_diseases_classification project/saved model/best_model_custom.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 70s 483ms/step - accuracy: 0.4004 - loss: 1.2935 - val_accuracy: 0.4282 - val_loss: 1.2158
# Epoch 4/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - accuracy: 0.4389 - loss: 1.2038
# Epoch 4: val_loss did not improve from 1.21577
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 83s 493ms/step - accuracy: 0.4389 - loss: 1.2037 - val_accuracy: 0.4217 - val_loss: 1.2877
# Epoch 5/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.4813 - loss: 1.1611
# Epoch 5: val_loss improved from 1.21577 to 1.11289, saving model to /home/mojtaba/eye_diseases_classification project/saved model/best_model_custom.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 69s 479ms/step - accuracy: 0.4813 - loss: 1.1610 - val_accuracy: 0.4856 - val_loss: 1.1129
# Epoch 6/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.4968 - loss: 1.1161
# Epoch 6: val_loss improved from 1.11289 to 1.08221, saving model to /home/mojtaba/eye_diseases_classification project/saved model/best_model_custom.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 86s 506ms/step - accuracy: 0.4968 - loss: 1.1162 - val_accuracy: 0.5274 - val_loss: 1.0822
# Epoch 7/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.4942 - loss: 1.1040
# Epoch 7: val_loss improved from 1.08221 to 1.04625, saving model to /home/mojtaba/eye_diseases_classification project/saved model/best_model_custom.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 79s 488ms/step - accuracy: 0.4943 - loss: 1.1041 - val_accuracy: 0.5366 - val_loss: 1.0463
# Epoch 8/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step - accuracy: 0.5055 - loss: 1.0869
# Epoch 8: val_loss did not improve from 1.04625
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 84s 502ms/step - accuracy: 0.5055 - loss: 1.0869 - val_accuracy: 0.5339 - val_loss: 1.0653
# Epoch 9/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.5340 - loss: 1.0489
# Epoch 9: val_loss did not improve from 1.04625
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 82s 500ms/step - accuracy: 0.5340 - loss: 1.0489 - val_accuracy: 0.3198 - val_loss: 1.5280
# Epoch 10/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.5714 - loss: 1.0315
# Epoch 10: val_loss did not improve from 1.04625
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 70s 488ms/step - accuracy: 0.5714 - loss: 1.0314 - val_accuracy: 0.4164 - val_loss: 1.3060
# Epoch 11/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.5997 - loss: 0.9505
# Epoch 11: val_loss did not improve from 1.04625
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 72s 498ms/step - accuracy: 0.5996 - loss: 0.9506 - val_accuracy: 0.5522 - val_loss: 1.0917
# Epoch 12/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.5971 - loss: 0.9372
# Epoch 12: val_loss improved from 1.04625 to 0.84689, saving model to /home/mojtaba/eye_diseases_classification project/saved model/best_model_custom.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 80s 483ms/step - accuracy: 0.5971 - loss: 0.9373 - val_accuracy: 0.6319 - val_loss: 0.8469
# Epoch 13/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step - accuracy: 0.6008 - loss: 0.9264
# Epoch 13: val_loss did not improve from 0.84689
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 83s 488ms/step - accuracy: 0.6009 - loss: 0.9263 - val_accuracy: 0.6319 - val_loss: 0.9163
# Epoch 14/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.6279 - loss: 0.9078
# Epoch 14: val_loss did not improve from 0.84689
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 84s 500ms/step - accuracy: 0.6278 - loss: 0.9078 - val_accuracy: 0.4125 - val_loss: 1.9201
# Epoch 15/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.6083 - loss: 0.9117
# Epoch 15: val_loss improved from 0.84689 to 0.78201, saving model to /home/mojtaba/eye_diseases_classification project/saved model/best_model_custom.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 82s 501ms/step - accuracy: 0.6084 - loss: 0.9115 - val_accuracy: 0.6762 - val_loss: 0.7820
# Epoch 16/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.6368 - loss: 0.8859
# Epoch 16: val_loss did not improve from 0.78201
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 79s 479ms/step - accuracy: 0.6367 - loss: 0.8858 - val_accuracy: 0.6332 - val_loss: 0.9429
# Epoch 17/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 0.6395 - loss: 0.8435
# Epoch 17: val_loss did not improve from 0.78201
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 69s 481ms/step - accuracy: 0.6395 - loss: 0.8435 - val_accuracy: 0.5836 - val_loss: 1.0174
# Epoch 18/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.6455 - loss: 0.8423
# Epoch 18: val_loss improved from 0.78201 to 0.72423, saving model to /home/mojtaba/eye_diseases_classification project/saved model/best_model_custom.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 85s 503ms/step - accuracy: 0.6455 - loss: 0.8422 - val_accuracy: 0.7350 - val_loss: 0.7242
# Epoch 19/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.6621 - loss: 0.7993
# Epoch 19: val_loss improved from 0.72423 to 0.66683, saving model to /home/mojtaba/eye_diseases_classification project/saved model/best_model_custom.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 80s 491ms/step - accuracy: 0.6622 - loss: 0.7991 - val_accuracy: 0.7350 - val_loss: 0.6668
# Epoch 20/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.7132 - loss: 0.7237
# Epoch 20: val_loss improved from 0.66683 to 0.66271, saving model to /home/mojtaba/eye_diseases_classification project/saved model/best_model_custom.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 84s 502ms/step - accuracy: 0.7133 - loss: 0.7235 - val_accuracy: 0.7376 - val_loss: 0.6627
# Epoch 21/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.7360 - loss: 0.6906
# Epoch 21: val_loss did not improve from 0.66271
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 72s 496ms/step - accuracy: 0.7359 - loss: 0.6906 - val_accuracy: 0.7285 - val_loss: 0.7143
# Epoch 22/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.7320 - loss: 0.6798
# Epoch 22: val_loss did not improve from 0.66271
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 72s 497ms/step - accuracy: 0.7321 - loss: 0.6797 - val_accuracy: 0.6279 - val_loss: 0.9142
# Epoch 23/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.7388 - loss: 0.6409
# Epoch 23: val_loss improved from 0.66271 to 0.51877, saving model to /home/mojtaba/eye_diseases_classification project/saved model/best_model_custom.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 72s 500ms/step - accuracy: 0.7388 - loss: 0.6408 - val_accuracy: 0.8251 - val_loss: 0.5188
# Epoch 24/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.7533 - loss: 0.6223
# Epoch 24: val_loss did not improve from 0.51877
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 69s 475ms/step - accuracy: 0.7533 - loss: 0.6223 - val_accuracy: 0.5522 - val_loss: 1.0585
# Epoch 25/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.7748 - loss: 0.5922
# Epoch 25: val_loss did not improve from 0.51877
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 70s 487ms/step - accuracy: 0.7748 - loss: 0.5921 - val_accuracy: 0.8094 - val_loss: 0.5214
# Epoch 26/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.7556 - loss: 0.6003
# Epoch 26: val_loss did not improve from 0.51877
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 68s 473ms/step - accuracy: 0.7557 - loss: 0.6001 - val_accuracy: 0.7324 - val_loss: 0.6956
# Epoch 27/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.7751 - loss: 0.5659
# Epoch 27: val_loss did not improve from 0.51877
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 72s 497ms/step - accuracy: 0.7752 - loss: 0.5657 - val_accuracy: 0.7598 - val_loss: 0.6539
# Epoch 28/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.7890 - loss: 0.5360
# Epoch 28: val_loss did not improve from 0.51877
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 72s 499ms/step - accuracy: 0.7891 - loss: 0.5360 - val_accuracy: 0.6684 - val_loss: 0.8624
# Epoch 29/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.7913 - loss: 0.5699
# Epoch 29: val_loss improved from 0.51877 to 0.46455, saving model to /home/mojtaba/eye_diseases_classification project/saved model/best_model_custom.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 69s 475ms/step - accuracy: 0.7912 - loss: 0.5699 - val_accuracy: 0.8460 - val_loss: 0.4645
# Epoch 30/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.7760 - loss: 0.5574
# Epoch 30: val_loss did not improve from 0.46455
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 84s 488ms/step - accuracy: 0.7761 - loss: 0.5571 - val_accuracy: 0.7520 - val_loss: 0.6689
# Epoch 31/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.8054 - loss: 0.5133
# Epoch 31: val_loss improved from 0.46455 to 0.38284, saving model to /home/mojtaba/eye_diseases_classification project/saved model/best_model_custom.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 72s 498ms/step - accuracy: 0.8055 - loss: 0.5132 - val_accuracy: 0.8616 - val_loss: 0.3828
# Epoch 32/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.7913 - loss: 0.4990
# Epoch 32: val_loss did not improve from 0.38284
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 82s 498ms/step - accuracy: 0.7913 - loss: 0.4990 - val_accuracy: 0.6305 - val_loss: 0.8845
# Epoch 33/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.8013 - loss: 0.5064
# Epoch 33: val_loss did not improve from 0.38284
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 82s 498ms/step - accuracy: 0.8013 - loss: 0.5062 - val_accuracy: 0.4491 - val_loss: 4.7819
# Epoch 34/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 0.8017 - loss: 0.4712
# Epoch 34: val_loss did not improve from 0.38284
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 71s 495ms/step - accuracy: 0.8018 - loss: 0.4711 - val_accuracy: 0.7820 - val_loss: 0.5507
# Epoch 35/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.8225 - loss: 0.4823
# Epoch 35: val_loss improved from 0.38284 to 0.34125, saving model to /home/mojtaba/eye_diseases_classification project/saved model/best_model_custom.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 81s 486ms/step - accuracy: 0.8226 - loss: 0.4821 - val_accuracy: 0.8655 - val_loss: 0.3413
# Epoch 36/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 0.8257 - loss: 0.4461
# Epoch 36: val_loss did not improve from 0.34125
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 68s 474ms/step - accuracy: 0.8257 - loss: 0.4461 - val_accuracy: 0.5248 - val_loss: 1.5533
# Epoch 37/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.8173 - loss: 0.4624
# Epoch 37: val_loss did not improve from 0.34125
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 70s 482ms/step - accuracy: 0.8174 - loss: 0.4623 - val_accuracy: 0.8708 - val_loss: 0.3875
# Epoch 38/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 0.8199 - loss: 0.4376
# Epoch 38: val_loss did not improve from 0.34125
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 71s 495ms/step - accuracy: 0.8200 - loss: 0.4376 - val_accuracy: 0.8590 - val_loss: 0.3848
# Epoch 39/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.8360 - loss: 0.4093
# Epoch 39: val_loss did not improve from 0.34125
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 82s 498ms/step - accuracy: 0.8360 - loss: 0.4094 - val_accuracy: 0.7298 - val_loss: 0.6497
# Epoch 40/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.8196 - loss: 0.4814
# Epoch 40: val_loss did not improve from 0.34125
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 70s 485ms/step - accuracy: 0.8197 - loss: 0.4812 - val_accuracy: 0.7337 - val_loss: 0.7021
# Epoch 41/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.8226 - loss: 0.4497
# Epoch 41: val_loss did not improve from 0.34125
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 81s 481ms/step - accuracy: 0.8226 - loss: 0.4495 - val_accuracy: 0.8512 - val_loss: 0.4296
# Epoch 42/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.8383 - loss: 0.4170
# Epoch 42: val_loss did not improve from 0.34125
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 84s 496ms/step - accuracy: 0.8383 - loss: 0.4170 - val_accuracy: 0.8264 - val_loss: 0.4792
# Epoch 43/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.8424 - loss: 0.4079
# Epoch 43: val_loss improved from 0.34125 to 0.32617, saving model to /home/mojtaba/eye_diseases_classification project/saved model/best_model_custom.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 80s 483ms/step - accuracy: 0.8423 - loss: 0.4079 - val_accuracy: 0.8877 - val_loss: 0.3262
# Epoch 44/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.8215 - loss: 0.4300
# Epoch 44: val_loss did not improve from 0.32617
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 80s 472ms/step - accuracy: 0.8216 - loss: 0.4299 - val_accuracy: 0.8446 - val_loss: 0.4632
# Epoch 45/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.8515 - loss: 0.3668
# Epoch 45: val_loss did not improve from 0.32617
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 85s 497ms/step - accuracy: 0.8515 - loss: 0.3668 - val_accuracy: 0.8681 - val_loss: 0.3686
# Epoch 46/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.8471 - loss: 0.4015
# Epoch 46: val_loss did not improve from 0.32617
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 71s 494ms/step - accuracy: 0.8471 - loss: 0.4016 - val_accuracy: 0.8433 - val_loss: 0.4563
# Epoch 47/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.8302 - loss: 0.4085
# Epoch 47: val_loss did not improve from 0.32617
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 71s 494ms/step - accuracy: 0.8302 - loss: 0.4085 - val_accuracy: 0.8538 - val_loss: 0.3715
# Epoch 48/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.8496 - loss: 0.3825
# Epoch 48: val_loss did not improve from 0.32617
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 82s 497ms/step - accuracy: 0.8496 - loss: 0.3825 - val_accuracy: 0.8460 - val_loss: 0.4093
# Epoch 49/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.8413 - loss: 0.3843
# Epoch 49: val_loss did not improve from 0.32617
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 77s 467ms/step - accuracy: 0.8413 - loss: 0.3843 - val_accuracy: 0.8512 - val_loss: 0.4394
# Epoch 50/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - accuracy: 0.8385 - loss: 0.3767
# Epoch 50: val_loss did not improve from 0.32617
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 71s 493ms/step - accuracy: 0.8385 - loss: 0.3767 - val_accuracy: 0.8172 - val_loss: 0.4998
# Epoch 51/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.8484 - loss: 0.3813
# Epoch 51: val_loss improved from 0.32617 to 0.32265, saving model to /home/mojtaba/eye_diseases_classification project/saved model/best_model_custom.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 72s 497ms/step - accuracy: 0.8484 - loss: 0.3813 - val_accuracy: 0.8930 - val_loss: 0.3226
# Epoch 52/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.8501 - loss: 0.3755
# Epoch 52: val_loss improved from 0.32265 to 0.30085, saving model to /home/mojtaba/eye_diseases_classification project/saved model/best_model_custom.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 72s 496ms/step - accuracy: 0.8501 - loss: 0.3756 - val_accuracy: 0.8930 - val_loss: 0.3008
# Epoch 53/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.8487 - loss: 0.3576
# Epoch 53: val_loss did not improve from 0.30085
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 79s 478ms/step - accuracy: 0.8487 - loss: 0.3577 - val_accuracy: 0.8668 - val_loss: 0.3996
# Epoch 54/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.8605 - loss: 0.3512
# Epoch 54: val_loss did not improve from 0.30085
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 84s 496ms/step - accuracy: 0.8605 - loss: 0.3512 - val_accuracy: 0.8721 - val_loss: 0.3591
# Epoch 55/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.8648 - loss: 0.3436
# Epoch 55: val_loss did not improve from 0.30085
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 79s 473ms/step - accuracy: 0.8648 - loss: 0.3436 - val_accuracy: 0.8969 - val_loss: 0.3107
# Epoch 56/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.8658 - loss: 0.3309
# Epoch 56: val_loss did not improve from 0.30085
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 70s 484ms/step - accuracy: 0.8657 - loss: 0.3311 - val_accuracy: 0.8695 - val_loss: 0.3393
# Epoch 57/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.8493 - loss: 0.3577
# Epoch 57: val_loss did not improve from 0.30085
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 81s 474ms/step - accuracy: 0.8493 - loss: 0.3576 - val_accuracy: 0.8760 - val_loss: 0.3626
# Epoch 58/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.8489 - loss: 0.3547
# Epoch 58: val_loss improved from 0.30085 to 0.27897, saving model to /home/mojtaba/eye_diseases_classification project/saved model/best_model_custom.keras
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 69s 482ms/step - accuracy: 0.8490 - loss: 0.3546 - val_accuracy: 0.8956 - val_loss: 0.2790
# Epoch 59/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - accuracy: 0.8656 - loss: 0.3355
# Epoch 59: val_loss did not improve from 0.27897
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 71s 493ms/step - accuracy: 0.8655 - loss: 0.3358 - val_accuracy: 0.8159 - val_loss: 0.5071
# Epoch 60/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.8415 - loss: 0.3804
# Epoch 60: val_loss did not improve from 0.27897
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 67s 466ms/step - accuracy: 0.8416 - loss: 0.3803 - val_accuracy: 0.8825 - val_loss: 0.3400
# Epoch 61/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.8607 - loss: 0.3376
# Epoch 61: val_loss did not improve from 0.27897
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 84s 478ms/step - accuracy: 0.8608 - loss: 0.3377 - val_accuracy: 0.8420 - val_loss: 0.4180
# Epoch 62/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.8648 - loss: 0.3334
# Epoch 62: val_loss did not improve from 0.27897
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 71s 492ms/step - accuracy: 0.8648 - loss: 0.3335 - val_accuracy: 0.8681 - val_loss: 0.3623
# Epoch 63/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.8617 - loss: 0.3403
# Epoch 63: val_loss did not improve from 0.27897
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 79s 473ms/step - accuracy: 0.8618 - loss: 0.3403 - val_accuracy: 0.8786 - val_loss: 0.3599
# Epoch 64/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 0.8726 - loss: 0.3165
# Epoch 64: val_loss did not improve from 0.27897
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 83s 480ms/step - accuracy: 0.8726 - loss: 0.3166 - val_accuracy: 0.8903 - val_loss: 0.3141
# Epoch 65/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.8657 - loss: 0.3355
# Epoch 65: val_loss did not improve from 0.27897
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 71s 492ms/step - accuracy: 0.8657 - loss: 0.3355 - val_accuracy: 0.8838 - val_loss: 0.3100
# Epoch 66/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.8705 - loss: 0.2984
# Epoch 66: val_loss did not improve from 0.27897
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 80s 474ms/step - accuracy: 0.8705 - loss: 0.2984 - val_accuracy: 0.8812 - val_loss: 0.3479
# Epoch 67/200
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 0.8742 - loss: 0.3155
# Epoch 67: val_loss did not improve from 0.27897
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 85s 495ms/step - accuracy: 0.8742 - loss: 0.3156 - val_accuracy: 0.8956 - val_loss: 0.3151
# Epoch 67: early stopping
# Restoring model weights from the end of the best epoch: 55.

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(13,5))
plt.plot(history.history['accuracy'],color="#E74C3C", marker='o')
plt.plot(history.history['val_accuracy'], color='#641E16', marker='h')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.figure(figsize=(13,5))
plt.plot(history.history['loss'],color="#E74C3C", marker='o')
plt.plot(history.history['val_loss'], color='#641E16', marker='h')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend( ['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Load the saved model
# If the best model is captured by the early stopping mechanism then best_model = model
# best_model = model

best_model = load_model(r'/home/mojtaba/eye_diseases_classification project/saved model/best_model_custom.keras')



# Evaluate the model
train_loss, train_accuracy = best_model.evaluate(train_dataset)
val_loss, val_accuracy = best_model.evaluate(val_dataset)
test_loss, test_accuracy = best_model.evaluate(test_dataset)

print(f"train loss: {train_loss}")
print(f"train accuracy: {train_accuracy}")
print('----'*6)
print(f"val loss: {val_loss}")
print(f"val accuracy: {val_accuracy}")
print('----'*6)
print(f"Test loss: {test_loss}")
print(f"Test accuracy: {test_accuracy}")
# Out:
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 40s 268ms/step - accuracy: 0.8841 - loss: 0.2924
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 166ms/step - accuracy: 0.8927 - loss: 0.2838
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 155ms/step - accuracy: 0.8908 - loss: 0.2770
# train loss: 0.2917798161506653
# train accuracy: 0.8815847039222717
# ------------------------
# val loss: 0.2789709270000458
# val accuracy: 0.8955613374710083
# ------------------------
# Test loss: 0.30607298016548157
# Test accuracy: 0.8825065493583679

# %%
# Assuming best_model is your trained Keras model

# Get the predicted labels from the model
y_pred = np.argmax( best_model.predict(test_dataset) , axis=1 ) # Convert probabilities to class indices
y_true = test_labels

# Compute confusion matrix
conf_mat = confusion_matrix(y_true, y_pred)

print("Confusion Matrix:")
print(conf_mat)

# Get the class labels from the LabelEncoder
class_labels = label_encoder.classes_

# Compute classification report
report = classification_report(y_true, y_pred, target_names=class_labels)

print("\nClassification Report:")
print(report)
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 151ms/step
# Confusion Matrix:
# [[192   0   7   9]
#  [  1 139   1   1]
#  [ 13   0 146  42]
#  [  3   0  13 199]]
#
# Classification Report:
#                       precision    recall  f1-score   support
#
#             cataract       0.92      0.92      0.92       208
# diabetic_retinopathy       1.00      0.98      0.99       142
#             glaucoma       0.87      0.73      0.79       201
#               normal       0.79      0.93      0.85       215
#
#             accuracy                           0.88       766
#            macro avg       0.90      0.89      0.89       766
#         weighted avg       0.89      0.88      0.88       766

# %%
#Confusion matrix
print('Total Number Of Test data: ', len(test_labels))

sn.set_style("white")
def plot_confusion_matrix(conf_mat, classes):
    """
    This function prints and plots the confusion matrix.
    """
    fig, ax = plt.subplots(figsize=(7,7)) # change the plot size
    disp = ConfusionMatrixDisplay(confusion_matrix=conf_mat, display_labels=classes)
    disp = disp.plot(include_values=True,cmap='viridis', ax=ax, xticks_rotation=45)
    plt.show()

# Get your confusion matrix
conf_mat = conf_mat

# Using label_encoder.classes_ guarantees that class_names matches
# the order that was used during the one-hot encoding process
class_names = label_encoder.classes_

# Now plot using the function
plot_confusion_matrix(conf_mat, class_names)
# Out:
# Total Number Of Test data:  766

# %%
# probability explanation in below function:
# For example, if the model predicts an image as class B with a probability of 0.7 (or 70%),
# the plot will show "Probability: 70%".
# This means the model is 70% confident that the image belongs to class B.


def plot_test_predictions(model, test_dataset, class_labels, num_images=20):
    """
    Plots the predictions of a model on the test dataset.

    Parameters:
    - model: Trained Keras model to be used for prediction.
    - test_dataset: TensorFlow dataset containing the test images and labels.
    - class_labels: List of class labels.
    - num_images: Number of test images to plot (default is 20).
    """

    # Initialize lists to accumulate images and labels
    images = []
    true_labels = []
    pred_labels = []
    pred_probs = []

    for batch_images, batch_labels in test_dataset:
        # Predict on the batch
        batch_pred_probs = model.predict(batch_images)
        batch_pred_labels = np.argmax(batch_pred_probs, axis=1)

        # Accumulate images and labels
        images.extend(batch_images)
        true_labels.extend(batch_labels)
        pred_labels.extend(batch_pred_labels)
        pred_probs.extend(np.max(batch_pred_probs, axis=1) * 100)

        if len(images) >= num_images:
            break

    # Plot the images with predictions
    plt.figure(figsize=(15, 20))
    for i in range(num_images):
        plt.subplot(5, 5, i + 1)
        plt.imshow(images[i])
        actual_label = class_labels[true_labels[i]]
        predicted_label = class_labels[pred_labels[i]]
        probability = pred_probs[i]  # Probability of the predicted class

        color = 'green' if actual_label == predicted_label else 'red'
        plt.title(f"Actual Label: {actual_label}\nPrediction: {predicted_label}\nProbability: {probability:.2f}%",
                  color=color, fontsize=12)
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# Use the function
plot_test_predictions(best_model, test_dataset, class_labels=class_names, num_images=20)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 724ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step

# %% [markdown]
# **TRANSFER** **LEARNING**

# %%
import pickle
from tensorflow.keras.models import load_model

# Load the best model saved by ModelCheckpoint
best_model = load_model(r'/home/mojtaba/eye_diseases_classification project/saved model/best_model_custom.keras')

# Save the model to a .pkl file
with open('best_model.pkl', 'wb') as file:
    pickle.dump(best_model, file)

print("Model saved as best_model.pkl")
# Out:
# Model saved as best_model.pkl
